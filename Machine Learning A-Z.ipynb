# %%
from IPython.display import SVG
SVG(filename='/content/drive/MyDrive/ESTADÍSTICA/Udemy_logo.svg')

# %% [markdown]
# <img alt="" width="220" src="data:image/svg+xml;base64,..." />

# %% [markdown]
# # **Machine Learning A-Z™**
